# %%
import pandas as pd

# %%
sell = pd.read_csv("bestsellers.csv")
titanic  = pd.read_csv("netflix_titles.csv", sep ='|', index_col=0)
house =  pd.read_csv("kc_house_data.csv")
netflix = pd.read_csv("netflix_titles.csv", sep= '|', index_col=0)
btc = pd.read_csv("coin_Bitcoin.csv")
happy = pd.read_csv("world-happiness-report-2021.csv", index_col =0)

# %%
happy
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
happy.sort_values("Healthy life expectancy", ascending= False, inplace = True)

# %%
happy.head()
# Out:
#                           Regional indicator  Ladder score  \
# Country name
# Singapore                     Southeast Asia         6.377
# Hong Kong S.A.R. of China          East Asia         5.477
# Japan                              East Asia         5.940
# Spain                         Western Europe         6.491
# Switzerland                   Western Europe         7.571
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Singapore                                           0.043         6.460
# Hong Kong S.A.R. of China                           0.049         5.573
# Japan                                               0.040         6.020
# Spain                                               0.042         6.574
# Switzerland                                         0.036         7.643
#
#                            lowerwhisker  Logged GDP per capita  \
# Country name
# Singapore                         6.293                 11.488
# ...

# %%
df = happy.sort_values(["Logged GDP per capita","Perceptions of corruption"], ascending = False)

# %%
df
# Out:
#                                 Regional indicator  Ladder score  \
# Country name
# Luxembourg                          Western Europe         7.324
# Singapore                           Southeast Asia         6.377
# Ireland                             Western Europe         7.085
# Switzerland                         Western Europe         7.571
# United Arab Emirates  Middle East and North Africa         6.561
# ...                                            ...           ...
# Liberia                         Sub-Saharan Africa         4.625
# Mozambique                      Sub-Saharan Africa         4.794
# Niger                           Sub-Saharan Africa         5.074
# Malawi                          Sub-Saharan Africa         3.600
# Burundi                         Sub-Saharan Africa         3.775
#
#                       Standard error of ladder score  upperwhisker  \
# Country name
# Luxembourg                                     0.037         7.396
# ...

# %%
df.head().plot(kind='bar', x="Logged GDP per capita", y="Perceptions of corruption")
# Out:
# <AxesSubplot:xlabel='Logged GDP per capita'>

# %%
happy.sort_index()
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
happy.sort_values("Regional indicator", key=lambda col: col.str.lower())
# Out:
#                                 Regional indicator  Ladder score  \
# Country name
# Albania                 Central and Eastern Europe         5.117
# Serbia                  Central and Eastern Europe         6.078
# Bosnia and Herzegovina  Central and Eastern Europe         5.813
# Hungary                 Central and Eastern Europe         5.992
# Lithuania               Central and Eastern Europe         6.255
# ...                                            ...           ...
# France                              Western Europe         6.690
# Italy                               Western Europe         6.483
# North Cyprus                        Western Europe         5.536
# Portugal                            Western Europe         5.929
# Iceland                             Western Europe         7.554
#
#                         Standard error of ladder score  upperwhisker  \
# Country name
# Albania                                          0.059         5.234
# ...

# %%
happy.loc[["Japan","India","China"]]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Japan                 East Asia         5.940                           0.040
# India                South Asia         3.819                           0.026
# China                 East Asia         5.339                           0.029
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Japan                6.020         5.861                 10.611
# India                3.869         3.769                  8.755
# China                5.397         5.281                  9.673
#
#               Social support  Healthy life expectancy  \
# Country name
# Japan                  0.884                   75.100
# India                  0.603                   60.633
# China                  0.811                   69.593
#
#               Freedom to make life choices  Generosity  \
# Country name
# Japan                                0.796      -0.258
# ...

# %%
happy.loc["China" : "India"]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# China                            East Asia         5.339
# Bahrain       Middle East and North Africa         6.647
# Slovakia        Central and Eastern Europe         6.331
# Uruguay        Latin America and Caribbean         6.431
# Argentina      Latin America and Caribbean         5.929
# ...                                    ...           ...
# Cambodia                    Southeast Asia         4.830
# Egypt         Middle East and North Africa         4.283
# Rwanda                  Sub-Saharan Africa         3.415
# Kenya                   Sub-Saharan Africa         4.607
# India                           South Asia         3.819
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# China                                  0.029         5.397         5.281
# Bahrain                                0.068         6.779         6.514
# ...

# %%
happy.iloc[1:11]
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Hong Kong S.A.R. of China              East Asia         5.477
# Japan                                  East Asia         5.940
# Spain                             Western Europe         6.491
# Switzerland                       Western Europe         7.571
# France                            Western Europe         6.690
# South Korea                            East Asia         5.845
# Australia                  North America and ANZ         7.183
# Cyprus                            Western Europe         6.223
# North Cyprus                      Western Europe         5.536
# Canada                     North America and ANZ         7.103
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Hong Kong S.A.R. of China                           0.049         5.573
# Japan                                               0.040         6.020
# ...

# %%
happy["Freedom to make life choices"].loc["India"]
# Out:
# 0.893

# %%
happy["Freedom to make life choices"].iloc[15 : 20]
# Out:
# Country name
# Austria    0.908
# Iceland    0.955
# Denmark    0.946
# Sweden     0.945
# Greece     0.582
# Name: Freedom to make life choices, dtype: float64
